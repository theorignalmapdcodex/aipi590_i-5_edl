# %% [markdown]
# <a href="https://colab.research.google.com/github/theorignalmapdcodex/aipi590_i-5_edl/blob/main/notebooks/explainable_deep_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🔃 **Downloading Files Externally [the dataset of use & the requirements.txt file] for Processing as well as Package Installation (With the Idea of Sharing to Others)**

# %%
# !pip install -U gdown  # Installing gdown if not already installed

# A - Grabbing actual file IDs from the Google Drive shared links
reqtxt_file_id = "1oXjGGCRqFioBEuaZ_9qtV74HfLIe81G1"

img1_file_id = "1v52fQxdroWV9MPU8ThS1QJAqBtbIa_St"
img2_file_id = "1BteZbCAiL5iyPKqpUWv9pJSf5xoVvysi"
img3_file_id = "1HNbAN0krlLJxn290er-fe7NJmHL6aaII"
img4_file_id = "1HNbAN0krlLJxn290er-fe7NJmHL6aaII"
img5_file_id = "1TpaeR27mXtEWiYr_WPKXNp7o3dY3Zazt"
img6_file_id = "1eFsC3o1Fy2RrR45ncS4i77kcBXGNFfLA"

# B - Saving file to local varible for ease of use
reqtxt_output_file = "requirements.txt"

img1_output_file = "zebra_img_1"
img2_output_file = "zebra_img_2"
img3_output_file = "zebra_img_3"
img4_output_file = "zebra_img_4"
img5_output_file = "zebra_img_5"
img6_output_file = "zebra_img_6"

# C - Download the requirements file
# !gdown "https://drive.google.com/uc?id={reqtxt_file_id}" -O {reqtxt_output_file}

# D - Downloading 6 Images
# !gdown "https://drive.google.com/uc?id={img1_file_id}" -O {img1_output_file}
# !gdown "https://drive.google.com/uc?id={img2_file_id}" -O {img2_output_file}
# !gdown "https://drive.google.com/uc?id={img3_file_id}" -O {img3_output_file}
# !gdown "https://drive.google.com/uc?id={img4_file_id}" -O {img4_output_file}
# !gdown "https://drive.google.com/uc?id={img5_file_id}" -O {img5_output_file}
# !gdown "https://drive.google.com/uc?id={img6_file_id}" -O {img6_output_file}



                      # ---- SUPPORT TAGGING ---- #
#----> via me on 6 Feb 25 @ 1:00am (referenced from old data science notebook)
#----> via Gemini AI on 5 Feb 25 @ 9:19pm but refined by me (introduced 'if clause')
#----> via DUKE-AI-XAI (AIPI590) global_explanations.ipynb file on 6 Feb 25 @ 1:25am

                      # ---- COMMITTING TO GITHUB ---- #
# Progressing with I-5, 30% done
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1oXjGGCRqFioBEuaZ_9qtV74HfLIe81G1
# To: /content/requirements.txt
# 100% 114/114 [00:00<00:00, 347kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1v52fQxdroWV9MPU8ThS1QJAqBtbIa_St
# To: /content/zebra_img_1
# 100% 1.12M/1.12M [00:00<00:00, 98.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BteZbCAiL5iyPKqpUWv9pJSf5xoVvysi
# To: /content/zebra_img_2
# 100% 101k/101k [00:00<00:00, 72.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1HNbAN0krlLJxn290er-fe7NJmHL6aaII
# To: /content/zebra_img_3
# 100% 34.1k/34.1k [00:00<00:00, 59.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1HNbAN0krlLJxn290er-fe7NJmHL6aaII
# To: /content/zebra_img_4
# 100% 34.1k/34.1k [00:00<00:00, 41.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TpaeR27mXtEWiYr_WPKXNp7o3dY3Zazt
# To: /content/zebra_img_5
# 100% 324k/324k [00:00<00:00, 16.9MB/s]
# Downloading...
# ...

# %% [markdown]
# >#### 🔗 **1. GitHub Link:**
# - Click [here](https://github.com/theorignalmapdcodex/aipi590_i-5_edl/blob/main/notebooks/explainable_deep_learn.ipynb) to access the *GitHub repository .ipynb* file for this assignment.

# %% [markdown]
# ##🥅 **Project Goal:**
# ### *The goal is to design and execute a study using deep learning explainability techniques to test a specific hypothesis about a model's understanding of a visual concept.  This involves formulating a testable hypothesis (null and alternative), selecting an appropriate explainability method (like saliency maps, feature visualization, etc.), conducting experiments to generate explanations, and analyzing those explanations to determine if they support or refute the hypothesis about the model's learned understanding of the concept.*

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 🛣️ Approach
# ### The study I will conduct will examine whether a `GoogleNet model` preferentially highlights the striped regions of zebras when classifying zebra images. The study would basically be a visual report that clearly presents the hypothesis ($H_0$ and $H_1$ highlighted below), the chosen explainable AI approach (`saliency maps`), the resulting visualizations and explanations, and a summary of the findings. The primary objective is to demonstrate a sound experimental design and analysis process, rather than achieving a particular outcome (acceptance or rejection of the null hypothesis).

# %% [markdown]
# ---

# %% [markdown]
# ## 🧪 Hypothesis:
# ### To achieve the above goal, I will formulate the below hypothesis to aid in achieving the project goal.

# %% [markdown]
# > ## $H_0$ ("null" hypothesis): The saliency maps generated for zebra images classified by the GoogleNet model do not preferentially highlight the striped regions of the zebra.

# %% [markdown]
# > ## $H_1$ ("alternative" hypothesis): The saliency maps generated for zebra images classified by the GoogleNet model preferentially highlight the striped regions of the zebra, indicating that the model focuses on these features for classification.(the "null" hypothesis, $H_0$)

# %%
# To ignore warnings for code output to look clean
import warnings
warnings.filterwarnings("ignore")

# %%
# NB: You can choose to un-comment and clone if not, the code book should run fine from 'gdown' approach
# import os

# # Remove Colab default sample_data if it exists
# if os.path.exists("./sample_data"):
#     !rm -r ./sample_data

# # Clone GitHub files to colab workspace
# repo_name = f'{aipi590_i-5_edl}'

# # Check if the repo already exists
# if not os.path.exists("/content/" + repo_name):
#     git_path = f'{https://github.com/theorignalmapdcodex/aipi590_i-5_edl.git}'
#     !git clone "{git_path}"
# else:
#     print(f"{aipi590_i-5_edl} already exists.")

# # Change working directory to location of notebook
# path_to_notebook = os.path.join("/content/" + aipi590_i-5_edl)
# %cd "{path_to_notebook}"
# %ls

# %% [markdown]
# ## 📚 **I. Libraries & Packages Installation**

# %% [markdown]
# Before I proceed to developing any `saliency map` on my test images, `zebras`, let's first install the right libraries and packages.

# %%
#Install the requirements for this package and included in requirements.txt file for the purposes of working on Colab independently
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# General packages for EDA, Plotting etc.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Packages for this assignment
# Model Utils
import tensorflow as tf

# Data Utils
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from keras.utils import get_file
import json
import os

# %% [markdown]
# ## ⚙️ **III. TITLE GOES HERE**

# %% [markdown]
# ## 💻 **IV. TITLE GOES HERE**

# %% [markdown]
# ## ✨ **V. TITLE GOES HERE**

# %% [markdown]
# ### **<mark>Extras</mark>**

# %% [markdown]
# ## 🅿️ **VI. TITLE GOES HERE**

# %% [markdown]
# > ## **📈 Plot #1: Sub-title goes here** 🌓

# %% [markdown]
# > ## **📉 Plot #2: Sub-title goes here** 🧊

# %% [markdown]
# > ## **📊 Plot #3: Sub-title goes here** 🫚

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 🔚 **Conclusion:**
#
# ## *Siummary of Key Findings:*
#
# > ### **1. Key Takeaways from PDP 1st Order Plots**
# - **Completion Rate** is the most influential factor affecting conversion, particularly around 40-50% completion.
# - **Engagement Time and Shares have minimal impact** on conversion in this dataset.
# - This suggests **improving content design around mid-completion** could enhance conversion rates.
#
# <mark>GeminiAI refined my output</mark>
